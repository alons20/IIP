# %%
"Mexico" #jose Alonso Orozco Juarez

# %%
a = 4
B = 9

if type (b)is not int :
  raise Exeption ("El valor de b debe ser un numero entero")

  elif b

# %%
a = 50
b = 50
if a < b:
  print(a, "Es menor wue", b)
elif a > b:
  print(a, "ES mayor que", b)
else:
  print(a, "Es igual que", b)
# Out:
# 50 Es igual que 50

# %%
a = int(input("Enter the first number"))
B = int(input("Enter the second number"))

if a < b:
  print(a, "Es igual que", b)
