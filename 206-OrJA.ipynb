# %%
print("Operadores matematicos")
print("Realiza la suma 4 + 4 =" , 4 + 4)
print("Realiza la suma 7 + 2 =" , 7 + 2)
print("Realiza la suma 8 + 4 =" , 8 + 4)
print("Realiza la suma 7 + 4 =" , 7 + 4)
print("Realiza la suma 5 + 9 =" , 5 + 9)
print("Realiza la suma 7 + 6 =" , 7 + 6)
print("Realiza la suma 2 + 7 =" , 2 + 7)
print("Realiza la suma 4 + 1 =" , 4 + 1)
print("Realiza la suma 3 + 4 =" , 3 + 4)
print("Realiza la suma 4 + 2 =" , 4 + 2)
# Out:
# Operadores matematicos
# Realiza la suma 4 + 4 = 8
# Realiza la suma 7 + 2 = 9
# Realiza la suma 8 + 4 = 12
# Realiza la suma 7 + 4 = 11
# Realiza la suma 5 + 9 = 14
# Realiza la suma 7 + 6 = 13
# Realiza la suma 2 + 7 = 9
# Realiza la suma 4 + 1 = 5
# Realiza la suma 3 + 4 = 7
# Realiza la suma 4 + 2 = 6

# %%
print("Operadores matematicos")
print("Realiza la multiplicacion 1 * 1 =" , 1 * 1)
print("Realiza la multiplicacion 2 * 9 =" , 2 * 9)
print("Realiza la multiplicacion 3 * 3 =" , 3 * 3)
print("Realiza la multiplicacion 4 * 2 =" , 4 * 2)
print("Realiza la multiplicacion 5 * 1 =" , 5 * 1)
print("Realiza la multiplicacion 1 * 5 =" , 1 * 5)
print("Realiza la multiplicacion 9 * 7 =" , 9 * 7)
print("Realiza la multiplicacion 8 * 1 =" , 8 * 1)
print("Realiza la multiplicacion 7 * 5 =" , 7 * 5)
print("Realiza la multiplicacion 6 * 7 =" , 6 * 7)
# Out:
# Operadores matematicos
# Realiza la multiplicacion 1 * 1 = 1
# Realiza la multiplicacion 2 * 9 = 18
# Realiza la multiplicacion 3 * 3 = 9
# Realiza la multiplicacion 4 * 2 = 8
# Realiza la multiplicacion 5 * 1 = 5
# Realiza la multiplicacion 1 * 5 = 5
# Realiza la multiplicacion 9 * 7 = 63
# Realiza la multiplicacion 8 * 1 = 8
# Realiza la multiplicacion 7 * 5 = 35
# Realiza la multiplicacion 6 * 7 = 42

# %%
print("Operadores matematicos")
print("Realiza la resta 1 - 3 =" , 1 - 3)
print("Realiza la resta 3 - 3 =" , 3 - 3)
print("Realiza la resta 5 - 2 =" , 5 - 2)
print("Realiza la resta 6 - 3 =" , 6 - 3)
print("Realiza la resta 7 - 4 =" , 7 - 4)
print("Realiza la resta 8 - 8 =" , 8 - 8)
print("Realiza la resta 9 - 5 =" , 9 - 5)
print("Realiza la resta 4 - 9 =" , 4 - 9)
print("Realiza la resta 7 - 1 =" , 7 - 1)
print("Realiza la resta 2 - 3 =" , 2 - 3)
# Out:
# Operadores matematicos
# Realiza la resta 1 - 3 = -2
# Realiza la resta 3 - 3 = 0
# Realiza la resta 5 - 2 = 3
# Realiza la resta 6 - 3 = 3
# Realiza la resta 7 - 4 = 3
# Realiza la resta 8 - 8 = 0
# Realiza la resta 9 - 5 = 4
# Realiza la resta 4 - 9 = -5
# Realiza la resta 7 - 1 = 6
# Realiza la resta 2 - 3 = -1

# %%
print("Operadores matematicos")
print("Realiza la divicion 2 / 4 =" , 2 / 4)
print("Realiza la divicion 4 / 8 =" , 4 / 8)
print("Realiza la divicion 4 / 6 =" , 4 / 6)
print("Realiza la divicion 5 / 7 =" , 5 / 7)
print("Realiza la divicion 4 / 4 =" , 4 / 4)
print("Realiza la divicion 9 / 18 =" , 9 / 18)
print("Realiza la divicion 6 / 13 =" , 6 / 13)
print("Realiza la divicion 7 / 4 =" , 7 / 4)
print("Realiza la divicion 2 / 9 =" , 2 / 9)
print("Realiza la divicion 1 / 4 =" , 1 / 4)
# Out:
# Operadores matematicos
# Realiza la divicion 2 / 4 = 0.5
# Realiza la divicion 4 / 8 = 0.5
# Realiza la divicion 4 / 6 = 0.6666666666666666
# Realiza la divicion 5 / 7 = 0.7142857142857143
# Realiza la divicion 4 / 4 = 1.0
# Realiza la divicion 9 / 18 = 0.5
# Realiza la divicion 6 / 13 = 0.46153846153846156
# Realiza la divicion 7 / 4 = 1.75
# Realiza la divicion 2 / 9 = 0.2222222222222222
# Realiza la divicion 1 / 4 = 0.25
