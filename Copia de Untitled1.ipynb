# %%
#Calculadora imc
peso = 57
altura = 1.87

imc = peso / (altura ** 2)
print(f'Tu IMC es: {imc:2f}')

if imc < 18.5:
      print("Bajo peso")

elif imc < 25:
      print("Peso normal")

elif imc < 30:
      print("Sobre peso")

else:
    print("Eres kilo mortal")
# Out:
# Tu IMC es: 16.300152
# Bajo peso
